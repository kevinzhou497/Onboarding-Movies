# %%
import numpy as np 
import pandas as pd 
import seaborn as sns 
import matplotlib.pyplot as plt 
from sklearn import preprocessing
from sklearn.preprocessing import PolynomialFeatures
from sklearn.model_selection import train_test_split 
from sklearn.linear_model import LinearRegression 


df = pd.read_csv('onlyNewFilmsNormAll.csv')
df_features = df[['imdb_score_scaled', 'gross_scaled']]
df_features = df_features.sort_values(by=['gross_scaled'])



df_features.dropna(subset=['gross_scaled'], inplace=True)
df_features.dropna(subset=['imdb_score_scaled'], inplace=True)


X = np.array(df_features['imdb_score_scaled']).reshape(-1, 1) 
y = np.array(df_features['gross_scaled']).reshape(-1, 1) 

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, random_state=0) 

 
lin_reg = LinearRegression()
lin_reg.fit(X, y)



#y_pred = regr.predict(X_test) 
#plt.scatter(X_test, y_test, color ='b') 
#plt.plot(X_test, y_pred, color ='k') 
  
#plt.show() 

plt.scatter(X, y, color='blue')
plt.plot(X, lin_reg.predict(X), color='red')
plt.title('Linear Regression')
plt.xlabel('imdb_score_scaled')
plt.ylabel('gross_scaled')
plt.show()

print("Slope:" + str(lin_reg.coef_))
print("Intercept: " + str(lin_reg.intercept_))
print("Test R^2: " + str(lin_reg.score(X_test, y_test)))
print("Train R^2: " + str(lin_reg.score(X_train, y_train)))
# Out:
# Slope:[[0.27253037]]
# Intercept: [-0.01280509]
# Test R^2: 0.06695674864249612
# Train R^2: 0.06122648786590401

# %%
import numpy as np 
import pandas as pd 
import seaborn as sns 
import matplotlib.pyplot as plt 
from sklearn import preprocessing
from sklearn.preprocessing import PolynomialFeatures
from sklearn.model_selection import train_test_split 
from sklearn.linear_model import LinearRegression 


df = pd.read_csv('onlyNewFilmsNormAll.csv')
df_features = df[['budget_scaled', 'gross_scaled']]
df_features = df_features.sort_values(by=['gross_scaled'])



df_features.dropna(subset=['gross_scaled'], inplace=True)
df_features.dropna(subset=['budget_scaled'], inplace=True)


X = np.array(df_features['budget_scaled']).reshape(-1, 1) 
y = np.array(df_features['gross_scaled']).reshape(-1, 1) 

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, random_state=0) 

 
lin_reg = LinearRegression()
lin_reg.fit(X, y)



#y_pred = regr.predict(X_test) 
#plt.scatter(X_test, y_test, color ='b') 
#plt.plot(X_test, y_pred, color ='k') 
  
#plt.show() 

plt.scatter(X, y, color='blue')
plt.plot(X, lin_reg.predict(X), color='red')
plt.title('Linear Regression')
plt.xlabel('budget_scaled')
plt.ylabel('gross_scaled')
plt.show()

print("Slope:" + str(lin_reg.coef_))
print("Intercept: " + str(lin_reg.intercept_))
print("Test R^2: " + str(lin_reg.score(X_test, y_test)))
print("Train R^2: " + str(lin_reg.score(X_train, y_train)))
# Out:
# Slope:[[0.70807804]]
# Intercept: [-0.02537227]
# Test R^2: 0.5356398341878268
# Train R^2: 0.4897550684365495

# %%
import numpy as np 
import pandas as pd 
import seaborn as sns 
import matplotlib.pyplot as plt 
from sklearn import preprocessing
from sklearn.preprocessing import PolynomialFeatures
from sklearn.model_selection import train_test_split 
from sklearn.linear_model import LinearRegression 


df = pd.read_csv('onlyNewFilmsNormAll.csv')
df_features = df[['num_voted_users_scaled', 'gross_scaled']]
df_features = df_features.sort_values(by=['gross_scaled'])



df_features.dropna(subset=['gross_scaled'], inplace=True)
df_features.dropna(subset=['num_voted_users_scaled'], inplace=True)


X = np.array(df_features['num_voted_users_scaled']).reshape(-1, 1) 
y = np.array(df_features['gross_scaled']).reshape(-1, 1) 

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, random_state=0) 

 
lin_reg = LinearRegression()
lin_reg.fit(X, y)



#y_pred = regr.predict(X_test) 
#plt.scatter(X_test, y_test, color ='b') 
#plt.plot(X_test, y_pred, color ='k') 
  
#plt.show() 

plt.scatter(X, y, color='blue')
plt.plot(X, lin_reg.predict(X), color='red')
plt.title('Linear Regression')
plt.xlabel('num_voted_users_scaled')
plt.ylabel('gross_scaled')
plt.show()

print("Slope:" + str(lin_reg.coef_))
print("Intercept: " + str(lin_reg.intercept_))
print("Test R^2: " + str(lin_reg.score(X_test, y_test)))
print("Train R^2: " + str(lin_reg.score(X_train, y_train)))
# Out:
# Slope:[[0.66603594]]
# Intercept: [-0.06115824]
# Test R^2: 0.5836597534954561
# Train R^2: 0.4598917272647879

# %%
import numpy as np 
import pandas as pd 
import seaborn as sns 
import matplotlib.pyplot as plt 
from sklearn import preprocessing
from sklearn.preprocessing import PolynomialFeatures
from sklearn.model_selection import train_test_split 
from sklearn.linear_model import LinearRegression 


df = pd.read_csv('onlyNewFilmsNormAll.csv')
df_features = df[['cast_total_facebook_likes_scaled', 'gross_scaled']]
df_features = df_features.sort_values(by=['gross_scaled'])



df_features.dropna(subset=['gross_scaled'], inplace=True)
df_features.dropna(subset=['cast_total_facebook_likes_scaled'], inplace=True)


X = np.array(df_features['cast_total_facebook_likes_scaled']).reshape(-1, 1) 
y = np.array(df_features['gross_scaled']).reshape(-1, 1) 

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, random_state=0) 

 
lin_reg = LinearRegression()
lin_reg.fit(X, y)



#y_pred = regr.predict(X_test) 
#plt.scatter(X_test, y_test, color ='b') 
#plt.plot(X_test, y_pred, color ='k') 
  
#plt.show() 

plt.scatter(X, y, color='blue')
plt.plot(X, lin_reg.predict(X), color='red')
plt.title('Linear Regression')
plt.xlabel('cast_total_facebook_likes_scaled')
plt.ylabel('gross_scaled')
plt.show()

print("Slope:" + str(lin_reg.coef_))
print("Intercept: " + str(lin_reg.intercept_))
print("Test R^2: " + str(lin_reg.score(X_test, y_test)))
print("Train R^2: " + str(lin_reg.score(X_train, y_train)))
# Out:
# Slope:[[0.23828218]]
# Intercept: [-0.01057759]
# Test R^2: 0.0006825775743332096
# Train R^2: 0.07003345369239698

# %%
import numpy as np 
import pandas as pd 
import seaborn as sns 
import matplotlib.pyplot as plt 
from sklearn import preprocessing
from sklearn.preprocessing import PolynomialFeatures
from sklearn.model_selection import train_test_split 
from sklearn.linear_model import LinearRegression 


df = pd.read_csv('onlyNewFilmsNormAll.csv')
df_features = df[['movie_facebook_likes_scaled', 'gross_scaled']]
df_features = df_features.sort_values(by=['gross_scaled'])



df_features.dropna(subset=['gross_scaled'], inplace=True)
df_features.dropna(subset=['movie_facebook_likes_scaled'], inplace=True)


X = np.array(df_features['movie_facebook_likes_scaled']).reshape(-1, 1) 
y = np.array(df_features['gross_scaled']).reshape(-1, 1) 

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, random_state=0) 

 
lin_reg = LinearRegression()
lin_reg.fit(X, y)



#y_pred = regr.predict(X_test) 
#plt.scatter(X_test, y_test, color ='b') 
#plt.plot(X_test, y_pred, color ='k') 
  
#plt.show() 

plt.scatter(X, y, color='blue')
plt.plot(X, lin_reg.predict(X), color='red')
plt.title('Linear Regression')
plt.xlabel('movie_facebook_likes_scaled')
plt.ylabel('gross_scaled')
plt.show()

print("Slope:" + str(lin_reg.coef_))
print("Intercept: " + str(lin_reg.intercept_))
print("Test R^2: " + str(lin_reg.score(X_test, y_test)))
print("Train R^2: " + str(lin_reg.score(X_train, y_train)))
# Out:
# Slope:[[0.3966647]]
# Intercept: [-0.02169855]
# Test R^2: 0.22593569831095886
# Train R^2: 0.16134208417310858

# %%
import numpy as np 
import pandas as pd 
import seaborn as sns 
import matplotlib.pyplot as plt 
from sklearn import preprocessing
from sklearn.preprocessing import PolynomialFeatures
from sklearn.model_selection import train_test_split 
from sklearn.linear_model import LinearRegression 


df = pd.read_csv('onlyNewFilmsNormAll.csv')
df_features = df[['num_critic_for_reviews_scaled', 'gross_scaled']]
df_features = df_features.sort_values(by=['gross_scaled'])



df_features.dropna(subset=['gross_scaled'], inplace=True)
df_features.dropna(subset=['num_critic_for_reviews_scaled'], inplace=True)


X = np.array(df_features['num_critic_for_reviews_scaled']).reshape(-1, 1) 
y = np.array(df_features['gross_scaled']).reshape(-1, 1) 

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, random_state=0) 

 
lin_reg = LinearRegression()
lin_reg.fit(X, y)



#y_pred = regr.predict(X_test) 
#plt.scatter(X_test, y_test, color ='b') 
#plt.plot(X_test, y_pred, color ='k') 
  
#plt.show() 

plt.scatter(X, y, color='blue')
plt.plot(X, lin_reg.predict(X), color='red')
plt.title('Linear Regression')
plt.xlabel('num_critic_for_reviews_scaled')
plt.ylabel('gross_scaled')
plt.show()

print("Slope:" + str(lin_reg.coef_))
print("Intercept: " + str(lin_reg.intercept_))
print("Test R^2: " + str(lin_reg.score(X_test, y_test)))
print("Train R^2: " + str(lin_reg.score(X_train, y_train)))
# Out:
# Slope:[[0.56072413]]
# Intercept: [-0.08387148]
# Test R^2: 0.32827977906769945
# Train R^2: 0.29270862681860355
